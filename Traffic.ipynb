# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnaviikommidi007/TrafficAnalysis/blob/main/Traffic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7fcfb3f3-7a26-467a-9cb7-813dc63a043d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fcfb3f3-7a26-467a-9cb7-813dc63a043d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_file = "archive (2).zip"   # Corrected ZIP filename

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall()

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'Metro_Interstate_Traffic_Volume.csv',
#  'archive (2).zip',
#  'sample_data']

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Metro_Interstate_Traffic_Volume.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
df.isnull().sum()
# Out:
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              61 non-null     object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %%
df["date_time"] = pd.to_datetime(df["date_time"])

# %%
df["holiday"]=df["holiday"].fillna("No holiday")

# %%
df.isnull().sum()
# Out:
# holiday                0
# temp                   0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# weather_main           0
# weather_description    0
# date_time              0
# traffic_volume         0
# dtype: int64

# %%
df["holiday"].unique()
# Out:
# array(['No holiday', 'Columbus Day', 'Veterans Day', 'Thanksgiving Day',
#        'Christmas Day', 'New Years Day', 'Washingtons Birthday',
#        'Memorial Day', 'Independence Day', 'State Fair', 'Labor Day',
#        'Martin Luther King Jr Day'], dtype=object)

# %%
df["weather_main"].unique()
# Out:
# array(['Clouds', 'Clear', 'Rain', 'Drizzle', 'Mist', 'Haze', 'Fog',
#        'Thunderstorm', 'Snow', 'Squall', 'Smoke'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  datetime64[ns]
#  8   traffic_volume       48204 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 3.3+ MB

# %%
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  \
# count  48204.000000  48204.000000  48204.000000  48204.000000
# mean     281.205870      0.334264      0.000222     49.362231
# min        0.000000      0.000000      0.000000      0.000000
# 25%      272.160000      0.000000      0.000000      1.000000
# 50%      282.450000      0.000000      0.000000     64.000000
# 75%      291.806000      0.000000      0.000000     90.000000
# max      310.070000   9831.300000      0.510000    100.000000
# std       13.338232     44.789133      0.008168     39.015750
#
#                            date_time  traffic_volume
# count                          48204    48204.000000
# mean   2016-01-05 10:46:16.773711616     3259.818355
# min              2012-10-02 09:00:00        0.000000
# 25%              2014-02-06 11:45:00     1193.000000
# 50%              2016-06-11 03:30:00     3380.000000
# 75%              2017-08-11 06:00:00     4933.000000
# ...

# %%
df['clouds_all'].unique()
# Out:
# array([ 40,  75,  90,   1,  20,   0, 100,  92,  99,  81,  50,  72,  56,
#         57,  93,  85,  68,  87,  91,  96,  48,  60,   8,  38,  46,  98,
#         86,  16,   6,  59,  54,  89,  78,  36,  17,  58,  63,  42,  25,
#         11,  13,  83,  70,  84,   3,  77,  88,  67,  97,  62,  32,   4,
#          5,   2,  44,  24,  76,  64,  80,  12])

# %%
df.head(6)
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0  No holiday  288.28      0.0      0.0          40       Clouds
# 1  No holiday  289.36      0.0      0.0          75       Clouds
# 2  No holiday  289.58      0.0      0.0          90       Clouds
# 3  No holiday  290.13      0.0      0.0          90       Clouds
# 4  No holiday  291.14      0.0      0.0          75       Clouds
# 5  No holiday  291.72      0.0      0.0           1        Clear
#
#   weather_description           date_time  traffic_volume
# 0    scattered clouds 2012-10-02 09:00:00            5545
# 1       broken clouds 2012-10-02 10:00:00            4516
# 2     overcast clouds 2012-10-02 11:00:00            4767
# 3     overcast clouds 2012-10-02 12:00:00            5026
# 4       broken clouds 2012-10-02 13:00:00            4918
# 5        sky is clear 2012-10-02 14:00:00            5181

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 4))
sns.histplot(df['traffic_volume'], kde=True, bins=30)
plt.title('Distribution of Traffic Volume')
plt.xlabel('Traffic Volume')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



sns.histplot(df['temp'], kde=True, color='orange')
plt.title('Distribution of Temperature')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='weather_main', order=df['weather_main'].value_counts().index)
plt.title('Frequency of Weather Conditions')
plt.xticks(rotation=45)
plt.show()

# %%
print(df['holiday'].value_counts())
# Out:
# holiday
# No holiday                   48143
# Labor Day                        7
# Christmas Day                    6
# Thanksgiving Day                 6
# Martin Luther King Jr Day        6
# New Years Day                    6
# Veterans Day                     5
# Columbus Day                     5
# Memorial Day                     5
# Washingtons Birthday             5
# State Fair                       5
# Independence Day                 5
# Name: count, dtype: int64

# %%
df['hour'] = df['date_time'].dt.hour
df['day_name'] = df['date_time'].dt.day_name()
df['month'] = df['date_time'].dt.month
df['is_weekend'] = df['date_time'].dt.dayofweek >= 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  datetime64[ns]
#  8   traffic_volume       48204 non-null  int64
#  9   hour                 48204 non-null  int32
#  10  day_name             48204 non-null  object
#  11  month                48204 non-null  int32
#  12  is_weekend           48204 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(3), int32(2), int64(2), object(4)
# memory usage: 4.1+ MB

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='hour', y='traffic_volume', estimator='mean')
plt.title('Average Traffic Volume by Hour')
plt.xlabel('Hour of Day (0-23)')
plt.ylabel('Average Traffic')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
numeric_cols = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df["traffic_volume"],
    bins=50,
    kde=True
)

plt.title("Traffic Volume Distribution")
plt.show()

# %%
df["hour"] = df["date_time"].dt.hour

# %%
hourly_traffic = df.groupby("hour")["traffic_volume"].mean()

hourly_traffic
# Out:
# hour
# 0      834.781051
# 1      516.449000
# 2      388.353640
# 3      371.090864
# 4      702.551889
# 5     2094.573437
# 6     4140.503594
# 7     4740.181337
# 8     4587.497115
# 9     4385.277502
# 10    4184.665544
# 11    4465.877561
# 12    4718.293095
# 13    4714.940682
# 14    4931.888776
# 15    5240.524302
# 16    5663.756539
# 17    5310.076048
# 18    4263.718530
# 19    3276.394187
# 20    2834.667509
# 21    2668.940464
# 22    2199.405717
# 23    1469.135294
# Name: traffic_volume, dtype: float64

# %%
df.groupby("rain_1h")["traffic_volume"].mean()
# Out:
# rain_1h
# 0.00       3257.336321
# 0.25       3261.965190
# 0.26       5945.500000
# 0.27       5130.000000
# 0.28       3736.782609
#               ...
# 28.70      1190.000000
# 31.75      4913.000000
# 44.45      4802.000000
# 55.63       315.000000
# 9831.30    5535.000000
# Name: traffic_volume, Length: 372, dtype: float64

# %%
df.head(100)
# Out:
#        holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0   No holiday  288.28      0.0      0.0          40       Clouds
# 1   No holiday  289.36      0.0      0.0          75       Clouds
# 2   No holiday  289.58      0.0      0.0          90       Clouds
# 3   No holiday  290.13      0.0      0.0          90       Clouds
# 4   No holiday  291.14      0.0      0.0          75       Clouds
# ..         ...     ...      ...      ...         ...          ...
# 95  No holiday  280.00      0.0      0.0          75       Clouds
# 96  No holiday  279.06      0.0      0.0          90       Clouds
# 97  No holiday  278.91      0.0      0.0          90       Clouds
# 98  No holiday  278.39      0.0      0.0          90       Clouds
# 99  No holiday  278.16      0.0      0.0          90       Clouds
#
#    weather_description           date_time  traffic_volume  hour  day_name  \
# 0     scattered clouds 2012-10-02 09:00:00            5545     9   Tuesday
# ...

# %%
df['rain_1h'].unique()
# Out:
# array([0.0000e+00, 2.5000e-01, 5.7000e-01, 3.8000e-01, 3.0000e-01,
#        2.9000e-01, 4.4000e-01, 3.6000e-01, 2.1600e+00, 3.3900e+00,
#        8.4000e-01, 7.6000e-01, 5.1000e-01, 6.9000e-01, 1.0000e+00,
#        1.2900e+00, 1.3400e+00, 1.8400e+00, 1.7000e+00, 4.7000e-01,
#        1.4100e+00, 1.4400e+00, 7.0000e-01, 3.1800e+00, 6.1000e-01,
#        6.4000e-01, 1.0200e+00, 5.4200e+00, 8.6400e+00, 5.7400e+00,
#        4.9800e+00, 3.6500e+00, 6.8000e-01, 4.6000e-01, 4.2000e-01,
#        1.5200e+00, 8.9000e-01, 1.4000e+00, 1.2190e+01, 2.2900e+00,
#        7.5400e+00, 6.9400e+00, 1.6380e+01, 1.7800e+00, 2.5400e+00,
#        9.1400e+00, 3.0500e+00, 1.6500e+00, 4.4450e+01, 3.8100e+00,
#        5.8400e+00, 3.5600e+00, 7.3700e+00, 1.3500e+00, 1.6000e+01,
#        1.0540e+01, 1.2700e+00, 5.0800e+00, 1.9900e+01, 2.5320e+01,
#        2.1420e+01, 5.5900e+00, 7.1100e+00, 5.9700e+00, 9.5300e+00,
#        2.0300e+00, 5.5630e+01, 1.3210e+01, 6.6000e+00, 5.6000e-01,
# ...

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(
    corr,
    annot=True
)
# Out:
# <Axes: >

# %%
def rush_hour(hour):
    if 6 <= hour <= 9:
        return "Morning Rush"
    elif 15 <= hour <= 17:
        return "Evening Rush"
    else:
        return "Normal"

df["rush_hour"] = df["hour"].apply(rush_hour)

# %%
df.head(10)
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0  No holiday  288.28      0.0      0.0          40       Clouds
# 1  No holiday  289.36      0.0      0.0          75       Clouds
# 2  No holiday  289.58      0.0      0.0          90       Clouds
# 3  No holiday  290.13      0.0      0.0          90       Clouds
# 4  No holiday  291.14      0.0      0.0          75       Clouds
# 5  No holiday  291.72      0.0      0.0           1        Clear
# 6  No holiday  293.17      0.0      0.0           1        Clear
# 7  No holiday  293.86      0.0      0.0           1        Clear
# 8  No holiday  294.14      0.0      0.0          20       Clouds
# 9  No holiday  293.10      0.0      0.0          20       Clouds
#
#   weather_description           date_time  traffic_volume  hour day_name  \
# 0    scattered clouds 2012-10-02 09:00:00            5545     9  Tuesday
# 1       broken clouds 2012-10-02 10:00:00            4516    10  Tuesday
# ...

# %%
corr = df.corr()

sns.heatmap(
    corr,
    annot=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_956/1376700459.py in <cell line: 0>()
# ----> 1 corr = df.corr()
#       2
#       3 sns.heatmap(
#       4     corr,
#       5     annot=True
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
# ...

# %%
from sklearn.preprocessing import LabelEncoder

df_corr = df.copy()

le = LabelEncoder()

df_corr["holiday"] = le.fit_transform(df_corr["holiday"])
df_corr["weather_main"] = le.fit_transform(df_corr["weather_main"])
df_corr["weather_description"] = le.fit_transform(df_corr["weather_description"])
df_corr["rush_hour"] = le.fit_transform(df_corr["rush_hour"])

# %%
corr = df_corr.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_956/546030646.py in <cell line: 0>()
# ----> 1 corr = df_corr.corr()
#       2
#       3 plt.figure(figsize=(12,8))
#       4 sns.heatmap(corr, annot=True, cmap="coolwarm")
#       5 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Features", fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_956/3925065167.py in <cell line: 0>()
#       5
#       6 sns.heatmap(
# ----> 7     corr_matrix,
#       8     annot=True,
#       9     cmap="coolwarm",
#
# NameError: name 'corr_matrix' is not defined

# %%
df.head()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0  No holiday  288.28      0.0      0.0          40       Clouds
# 1  No holiday  289.36      0.0      0.0          75       Clouds
# 2  No holiday  289.58      0.0      0.0          90       Clouds
# 3  No holiday  290.13      0.0      0.0          90       Clouds
# 4  No holiday  291.14      0.0      0.0          75       Clouds
#
#   weather_description           date_time  traffic_volume  hour day_name  \
# 0    scattered clouds 2012-10-02 09:00:00            5545     9  Tuesday
# 1       broken clouds 2012-10-02 10:00:00            4516    10  Tuesday
# 2     overcast clouds 2012-10-02 11:00:00            4767    11  Tuesday
# 3     overcast clouds 2012-10-02 12:00:00            5026    12  Tuesday
# 4       broken clouds 2012-10-02 13:00:00            4918    13  Tuesday
#
#    month  is_weekend     rush_hour
# 0     10       False  Morning Rush
# 1     10       False        Normal
# ...

# %%
# !git clone https://github.com/vaishnavikommdi007/Trafficanalysis.git
# Out:
# Cloning into 'Trafficanalysis'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !ls
# Out:
# 'archive (2).zip'   Metro_Interstate_Traffic_Volume.csv   sample_data

# %%
# !mv Traffic.ipynb TrafficAnalysis/
# Out:
# mv: cannot stat 'Traffic.ipynb': No such file or directory

# %%
df = df.sort_values("date_time")

# %%
X = df.drop("traffic_volume", axis=1)
y = df["traffic_volume"]

# %%
split_index = int(len(df) * 0.8)

X_train = X.iloc[:split_index]
X_test = X.iloc[split_index:]

y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]

# %%
print("Training Features:", X_train.shape)
print("Testing Features:", X_test.shape)

print("Training Target:", y_train.shape)
print("Testing Target:", y_test.shape)
# Out:
# Training Features: (38563, 13)
# Testing Features: (9641, 13)
# Training Target: (38563,)
# Testing Target: (9641,)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38563 entries, 0 to 38563
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              38563 non-null  object
#  1   temp                 38563 non-null  float64
#  2   rain_1h              38563 non-null  float64
#  3   snow_1h              38563 non-null  float64
#  4   clouds_all           38563 non-null  int64
#  5   weather_main         38563 non-null  object
#  6   weather_description  38563 non-null  object
#  7   date_time            38563 non-null  datetime64[ns]
#  8   hour                 38563 non-null  int32
#  9   day_name             38563 non-null  object
#  10  month                38563 non-null  int32
#  11  is_weekend           38563 non-null  bool
#  12  rush_hour            38563 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(3), int32(2), int64(1), object(5)
# memory usage: 3.6+ MB

# %%
categorical_cols = X_train.select_dtypes(include=['object']).columns

print(categorical_cols)
# Out:
# Index(['holiday', 'weather_main', 'weather_description', 'day_name',
#        'rush_hour'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            'cat',
            OneHotEncoder(handle_unknown='ignore'),
            categorical_cols
        )
    ],
    remainder='passthrough'
)

# %%
X_train_encoded = preprocessor.fit_transform(X_train)

X_test_encoded = preprocessor.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# /tmp/ipykernel_956/3574055640.py in <cell line: 0>()
# ----> 1 X_train_encoded = preprocessor.fit_transform(X_train)
#       2
#       3 X_test_encoded = preprocessor.transform(X_test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38563 entries, 0 to 38563
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              38563 non-null  object
#  1   temp                 38563 non-null  float64
#  2   rain_1h              38563 non-null  float64
#  3   snow_1h              38563 non-null  float64
#  4   clouds_all           38563 non-null  int64
#  5   weather_main         38563 non-null  object
#  6   weather_description  38563 non-null  object
#  7   date_time            38563 non-null  datetime64[ns]
#  8   hour                 38563 non-null  int32
#  9   day_name             38563 non-null  object
#  10  month                38563 non-null  int32
#  11  is_weekend           38563 non-null  bool
#  12  rush_hour            38563 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(3), int32(2), int64(1), object(5)
# memory usage: 3.6+ MB

# %%
X_train = X_train.drop(columns=["date_time"])
X_test = X_test.drop(columns=["date_time"])

# %%
X_train_encoded = preprocessor.fit_transform(X_train)

X_test_encoded = preprocessor.transform(X_test)

# %%
print(X_train_encoded.shape)
print(X_test_encoded.shape)
# Out:
# (38563, 78)
# (9641, 78)

# %%
X_test_encoded.shape
# Out:
# (9641, 78)

# %%
feature_names = preprocessor.get_feature_names_out()

print(feature_names)
# Out:
# ['cat__holiday_Christmas Day' 'cat__holiday_Columbus Day'
#  'cat__holiday_Independence Day' 'cat__holiday_Labor Day'
#  'cat__holiday_Martin Luther King Jr Day' 'cat__holiday_Memorial Day'
#  'cat__holiday_New Years Day' 'cat__holiday_No holiday'
#  'cat__holiday_State Fair' 'cat__holiday_Thanksgiving Day'
#  'cat__holiday_Veterans Day' 'cat__holiday_Washingtons Birthday'
#  'cat__weather_main_Clear' 'cat__weather_main_Clouds'
#  'cat__weather_main_Drizzle' 'cat__weather_main_Fog'
#  'cat__weather_main_Haze' 'cat__weather_main_Mist'
#  'cat__weather_main_Rain' 'cat__weather_main_Smoke'
#  'cat__weather_main_Snow' 'cat__weather_main_Squall'
#  'cat__weather_main_Thunderstorm' 'cat__weather_description_SQUALLS'
#  'cat__weather_description_Sky is Clear'
#  'cat__weather_description_broken clouds'
#  'cat__weather_description_drizzle' 'cat__weather_description_few clouds'
#  'cat__weather_description_fog' 'cat__weather_description_freezing rain'
#  'cat__weather_description_haze'
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train_encoded,y_train)
lr_pred=lr.predict(X_test_encoded)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import numpy as np
print("Linear Regression")
print("MAE:", mean_absolute_error(y_test, lr_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, lr_pred)))
print("R²:", r2_score(y_test, lr_pred))
# Out:
# Linear Regression
# MAE: 1206.9595589068858
# RMSE: 1425.3036024875935
# R²: 0.4753005297525521

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(random_state=42)

dt.fit(X_train_encoded, y_train)

dt_pred = dt.predict(X_test_encoded)

print("Decision Tree")
print("MAE:", mean_absolute_error(y_test, dt_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, dt_pred)))
print("R²:", r2_score(y_test, dt_pred))
# Out:
# Decision Tree
# MAE: 402.9689347578052
# RMSE: 717.5739346222148
# R²: 0.8670068814739174

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train_encoded, y_train)

rf_pred = rf.predict(X_test_encoded)

# %%
print("Random Forest")
print("MAE:", mean_absolute_error(y_test, rf_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, rf_pred)))
print("R²:", r2_score(y_test, rf_pred))
# Out:
# Random Forest
# MAE: 307.09945700406496
# RMSE: 549.5862795682357
# R²: 0.9219868841333219

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(
    n_estimators=400,
    learning_rate=0.06,
    max_depth=5,
    random_state=42
)
gbr.fit(X_train_encoded, y_train)
gbr_pred = gbr.predict(X_test_encoded)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
print("Gradient Boosting")
print("MAE:",
      mean_absolute_error(y_test, gbr_pred))
print("RMSE:",
      np.sqrt(mean_squared_error(y_test, gbr_pred)))
print("R²:",
      r2_score(y_test, gbr_pred))
# Out:
# Gradient Boosting
# MAE: 286.88299626084745
# RMSE: 506.1984317830308
# R²: 0.9338183712921169

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=400,
    learning_rate=0.06,
    max_depth=5,
    random_state=42
)

# Ensure X_train_encoded and X_test_encoded are dense arrays
# as OneHotEncoder can output sparse matrices
if hasattr(X_train_encoded, 'toarray'):
    X_train_xgb = X_train_encoded.toarray()
else:
    X_train_xgb = X_train_encoded

if hasattr(X_test_encoded, 'toarray'):
    X_test_xgb = X_test_encoded.toarray()
else:
    X_test_xgb = X_test_encoded

xgb_model.fit(X_train_xgb, y_train)
y_pred_xgb = xgb_model.predict(X_test_xgb)

# %%
print(X_train.dtypes)
# Out:
# temp                             float64
# rain_1h                          float64
# snow_1h                          float64
# clouds_all                         int64
# date_time                 datetime64[ns]
#                                ...
# day_name_Thursday                   bool
# day_name_Tuesday                    bool
# day_name_Wednesday                  bool
# rush_hour_Morning Rush              bool
# rush_hour_Normal                    bool
# Length: 74, dtype: object

# %%
df_encoded = pd.get_dummies(
    df,
    columns=[
        "holiday",
        "weather_main",
        "weather_description",
        "day_name",
        "rush_hour"
    ],
    drop_first=True
)

# %%
X = df_encoded.drop("traffic_volume", axis=1)
y = df_encoded["traffic_volume"]

# %%
split = int(len(df_encoded) * 0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=400,
    learning_rate=0.06,
    max_depth=5,
    random_state=42
)

# Ensure X_train_encoded and X_test_encoded are dense arrays
# as OneHotEncoder can output sparse matrices
if hasattr(X_train_encoded, 'toarray'):
    X_train_xgb = X_train_encoded.toarray()
else:
    X_train_xgb = X_train_encoded

if hasattr(X_test_encoded, 'toarray'):
    X_test_xgb = X_test_encoded.toarray()
else:
    X_test_xgb = X_test_encoded

xgb_model.fit(X_train_xgb, y_train)

y_pred = xgb_model.predict(X_test_xgb)

# %%
print(X_train.dtypes)
# Out:
# temp                             float64
# rain_1h                          float64
# snow_1h                          float64
# clouds_all                         int64
# date_time                 datetime64[ns]
#                                ...
# day_name_Thursday                   bool
# day_name_Tuesday                    bool
# day_name_Wednesday                  bool
# rush_hour_Morning Rush              bool
# rush_hour_Normal                    bool
# Length: 74, dtype: object

# %%
df_encoded = df_encoded.drop("date_time", axis=1)

# %%
X = X.drop("date_time", axis=1)

# %%
print(X.dtypes)
# Out:
# temp                      float64
# rain_1h                   float64
# snow_1h                   float64
# clouds_all                  int64
# hour                        int32
#                            ...
# day_name_Thursday            bool
# day_name_Tuesday             bool
# day_name_Wednesday           bool
# rush_hour_Morning Rush       bool
# rush_hour_Normal             bool
# Length: 73, dtype: object

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=1000,
    learning_rate=0.001,
    max_depth=5,
    random_state=42
)

# Ensure X_train_encoded and X_test_encoded are dense arrays
# as OneHotEncoder can output sparse matrices
if hasattr(X_train_encoded, 'toarray'):
    X_train_xgb = X_train_encoded.toarray()
else:
    X_train_xgb = X_train_encoded

if hasattr(X_test_encoded, 'toarray'):
    X_test_xgb = X_test_encoded.toarray()
else:
    X_test_xgb = X_test_encoded

xgb_model.fit(X_train_xgb, y_train)

y_pred = xgb_model.predict(X_test_xgb)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred_xgb)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
r2 = r2_score(y_test, y_pred_xgb)

print("XGBoost")
print("MAE:", mae)
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# XGBoost
# MAE: 286.43133544921875
# RMSE: 504.8155758541925
# R²: 0.9341794848442078

# %%
pip install lightgbm
